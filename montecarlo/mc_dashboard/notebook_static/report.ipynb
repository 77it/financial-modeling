# %% [markdown]
# # Static Report
# Questo notebook mostra come ricalcolare percentili e disegnare grafici statici per PDF.

# %%
from pathlib import Path
import pandas as pd
from core.loader import load_forecast_json
from core.transform import compute_percentiles
p = Path('../data/example.json')
df, meta, raw = load_forecast_json(p)
compute_percentiles(df).head()
